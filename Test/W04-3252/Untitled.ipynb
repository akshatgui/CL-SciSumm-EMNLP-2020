# %%
def clean(line,root,final1,final2):
    line = line.split("|")
    cit_2 , ref_2 = line[6].split("Citation Text:")[1].strip() , line[8].split("Reference Text:")[1].strip()
    cit_2 = cit_2.split(" >")[1].split("</S>")[0]
    ref_2 = ref_2.split(" >")[1:]
    ref_2 = [ i.split("</S>")[0] for i in ref_2]
    #print(ref_2)
    
    ans=cit_2
    for a in root:
        for b in a:
            flag=0
            final1.append(cit_2)
            final2.append(b.text)
            for i in ref_2:
                if i in b.text:
                    out.append("1")
                    flag=1
                    break
                
            
            if flag==0:
                out.append("0")
    
    
    return ans

# %%
out=[]
final1=[]
final2=[]
import os 

for k in os.listdir("./Test"):
    

    import xml.etree.ElementTree as ET
    tree = ET.parse("./Test/"+k+"/Reference_XML/"+k+".xml")
    root = tree.getroot()


    with open("./Test/"+k+"/annotation/"+k+".ann.txt") as f:
        data=f.read()
        arr=[]
        data = [ clean(i,root,final1,final2) for i in data.split("\n") if i ]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-3162c165db1b> in <module>
#       4 import os
#       5
# ----> 6 for k in os.listdir("./Test"):
#       7
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: './Test'

# %%
import pandas as pd
d={'col1':final1,'col2':final2, 'col3':out}
df = pd.DataFrame(data=d)

# %%
df[df["col3"]=="1"]
# Out:
#                                                    col1  \
# 6     In this paper, we show that a method for extra...
# 159   In this paper, we show that a method for extra...
# 181   Earlier experiments with graph-based ranking a...
# 318   Earlier experiments with graph-based ranking a...
# 523
# 524
# 698
# 699
# 709   Text Rank (TR) This is a graph-based sum maris...
# 817   Text Rank (TR) This is a graph-based sum maris...
# 884   TextRank (Mihalcea and Tarau, 2004) is one of ...
# 1048  TextRank (Mihalcea and Tarau, 2004) is one of ...
# 1185  PageRank score: as described in (Mihalcea and ...
# 1186  PageRank score: as described in (Mihalcea and ...
# 1251  Note, by the way, that although our graphs are...
# 1255  Note, by the way, that although our graphs are...
# 1424  Unsupervised approaches have also been propose...
# 1573  Unsupervised approaches have also been propose...
# 1575  In this paper, we adopt a variant of TextRank ...
# 1748  In this paper, we adopt a variant of TextRank ...
# 1846  More recently, Mihalcea and Tarau (2004) propo...
# 1900  More recently, Mihalcea and Tarau (2004) propo...
# 1925  If substep 1) is performed on each single docu...
# 1932  If substep 1) is performed on each single docu...
# 2129  As in Mihalcea and Tarau (2004), the documents...
# 2250  As in Mihalcea and Tarau (2004), the documents...
# 2298  Meanwhile, Mihalcea and Tarau (2004) presented...
# 2299  Meanwhile, Mihalcea and Tarau (2004) presented...
# 2459  As an example of an unsupervised keyphrase ext...
# 2587  As an example of an unsupervised keyphrase ext...
# 2668  Existing methods usually use term co occurrenc...
# 2683  Existing methods usually use term co occurrenc...
# 2800  Starting with TextRank (Mihalcea and Tarau,200...
# 2806  Starting with TextRank (Mihalcea and Tarau,200...
# 3059  The dataset is used in both (Hulth, 2003) and ...
# 3062  The dataset is used in both (Hulth, 2003) and ...
# 3234  We use the uncontrolled key phrases for evalua...
# 3237  We use the uncontrolled key phrases for evalua...
# 3409  In (Mihalcea and Tarau, 2004), due to the unsu...
# 3414  In (Mihalcea and Tarau, 2004), due to the unsu...
#
#                                                    col2 col3
# 6     Such text-oriented ranking methods can be appl...    1
# 159   Finally, another advantage of TextRank over pr...    1
# 181   Such text-oriented ranking methods can be appl...    1
# 318   We evaluate the TextRank sentence extraction a...    1
# 523   In particular, we proposed and evaluated two i...    1
# 524   An important aspect of TextRank is that it doe...    1
# 698   In particular, we proposed and evaluated two i...    1
# 699   An important aspect of TextRank is that it doe...    1
# 709   Graph-based ranking algorithms are essentially...    1
# 817   For the task of sentence extraction, the goal ...    1
# 884   Graph-based ranking algorithms are essentially...    1
# 1048  In particular, we proposed and evaluated two i...    1
# 1185  Formally, given two sentences and ,with a sent...    1
# 1186  The resulting graph is highly connected, with ...    1
# 1251  For loosely connected graphs, with the number ...    1
# 1255  However, in our model the graphs are build fro...    1
# 1424  HITS (Kleinberg, 1999) or Positional Function ...    1
# 1573  In particular, we proposed and evaluated two i...    1
# 1575  In this paper, we introduce TextRank – a graph...    1
# 1748  In particular, we proposed and evaluated two i...    1
# 1846  Our system consists of the TextRank approach d...    1
# 1900  Evaluation takes into account (a) all words; (...    1
# 1925  In this paper, we introduce TextRank – a graph...    1
# 1932  In this paper, we introduce the TextRank graph...    1
# 2129  In the context of Web surfing, it is unusual f...    1
# 2250  Evaluation takes into account (a) all words; (...    1
# 2298  It is important to notice that although the Te...    1
# 2299  HITS (Kleinberg, 1999) or Positional Function ...    1
# 2459  Graph-based ranking algorithms are essentially...    1
# 2587  The text is therefore represented as a weighte...    1
# 2668  The simplest possible approach is perhaps to u...    1
# 2683  We are using a co-occurrence relation, control...    1
# 2800  In this paper, we introduce TextRank – a graph...    1
# 2806  Such text-oriented ranking methods can be appl...    1
# 3059  This is the same test data set as used in the ...    1
# 3062  We follow the evaluation approach from (Hulth,...    1
# 3234  This is the same test data set as used in the ...    1
# 3237  We follow the evaluation approach from (Hulth,...    1
# 3409  This is the same test data set as used in the ...    1
# 3414  Since our approach is completely unsupervised,...    1

# %%
df.to_csv('file1.csv',index=False)
